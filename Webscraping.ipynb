# %%
from bs4 import  BeautifulSoup as bs
import requests

# %%
link="https://www.amazon.in/gp/aw/d/B0BX9ZZ99D/?th=1"

# %%
page=requests.get(link)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>\n<link rel="preconnect" href="https://completion.amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n\n<!-- sp:end-feature:csm:head-open
# ...

# %%
soup=bs(page.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# ...

# %%
names=soup.find_all("span",class_="a-profile-name")

# %%
names
# Out:
# [<span class="a-profile-name">POCO C55 (Power Black, 128 GB) (6 GB RAM)</span>,
#  <span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">Nandkumar Pawar</span>,
#  <span class="a-profile-name">Nandkumar Pawar</span>,
#  <span class="a-profile-name">Gopal</span>,
#  <span class="a-profile-name">Anand kumar singh</span>,
#  <span class="a-profile-name">Srinivas</span>,
#  <span class="a-profile-name">Paulami Laha</span>,
#  <span class="a-profile-name">Paulami Laha</span>,
#  <span class="a-profile-name">Sanskriti Tagore</span>,
#  <span class="a-profile-name">MUKTHESH</span>,
#  <span class="a-profile-name">Sonu k.</span>,
#  <span class="a-profile-name">Sonu k.</span>]

# %%
cust_names=[]
for i in range(len(names)):
    cust_names.append(names[i].get_text)
# Out:
# 'Amazon Customer'

# %%
cust_names=[]
for i in range(len(names)):
    cust_names.append(names[i].get_text())

# %%
cust_names
# Out:
# ['POCO C55 (Power Black, 128 GB) (6 GB RAM)',
#  'Amazon Customer',
#  'Amazon Customer',
#  'Nandkumar Pawar',
#  'Nandkumar Pawar',
#  'Gopal',
#  'Anand kumar singh',
#  'Srinivas',
#  'Paulami Laha',
#  'Paulami Laha',
#  'Sanskriti Tagore',
#  'MUKTHESH',
#  'Sonu k.',
#  'Sonu k.']

# %%
cust_names.pop(1)
# Out:
# 'Amazon Customer'

# %%
cust_names.pop(2)
# Out:
# 'Nandkumar Pawar'

# %%
cust_names.remove("Paulami Laha")

# %%
cust_names.remove("Sonu k.")

# %%
cust_names
# Out:
# ['POCO C55 (Power Black, 128 GB) (6 GB RAM)',
#  'Amazon Customer',
#  'Nandkumar Pawar',
#  'Gopal',
#  'Anand kumar singh',
#  'Srinivas',
#  'Paulami Laha',
#  'Sanskriti Tagore',
#  'MUKTHESH',
#  'Sonu k.']

# %%
reviews=soup.find_all("div",class_="a-expander-collapsed-height a-row a-expander-container a-expander-partial-collapse-container")

# %%
reviews
# Out:
# [<div class="a-expander-collapsed-height a-row a-expander-container a-expander-partial-collapse-container" data-a-expander-collapsed-height="300" data-a-expander-name="review_text_read_more" style="max-height:300px"><div aria-expanded="false" class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content" data-hook="review-collapsed">
#  <span>Plus points:<br>1. 6gb RAM + good Processor at this price 🤩<br/>2. Storage 128gb at this price 🤩<br/>3. Good quality screen. 😃<br/>4. Low price 🤩<br/>5. Good looks. 😃<br/>6. Good battery life. 😃<br/>7. Okish camera. 🙂<br/>  (Don't be impressed with number 50MP)<br/><br/>Cons:<br/>1. No C type charging port. 😑<br/>(You can keep it if it doesn't bothers you like my dad.)</br></span>
# ...

# %%
cust_reviews=[]
for i in range(len(reviews)):
    cust_reviews.append(reviews[i].get_text())

# %%
cust_reviews
# Out:
# ["\nPlus points:1. 6gb RAM + good Processor at this price 🤩2. Storage 128gb at this price 🤩3. Good quality screen. 😃4. Low price 🤩5. Good looks. 😃6. Good battery life. 😃7. Okish camera. 🙂  (Don't be impressed with number 50MP)Cons:1. No C type charging port. 😑(You can keep it if it doesn't bothers you like my dad.)\nRead more",
#  '\nDisplay okBattery okLight weightGood for normal useCamera unsatisfied...\nRead more',
#  '\nHello friends below mention are few review about POCO C55* By Look phone is nice* In this rang 7500/- nice phone* As I have buy this Phone to gift my mother & she is not using FB;Insta;Linkedin and social mediaso as of now phone is running very smooth* Battery is good* Camera at this rang is goodCons:* Refresh rate we can not change.* U will not get Phone Pin to open SIM tray\nRead more',
# ...

# %%
customer_reviews=[i.strip("\n") for i in cust_reviews]

# %%
customer_reviews
# Out:
# ["Plus points:1. 6gb RAM + good Processor at this price 🤩2. Storage 128gb at this price 🤩3. Good quality screen. 😃4. Low price 🤩5. Good looks. 😃6. Good battery life. 😃7. Okish camera. 🙂  (Don't be impressed with number 50MP)Cons:1. No C type charging port. 😑(You can keep it if it doesn't bothers you like my dad.)\nRead more",
#  'Display okBattery okLight weightGood for normal useCamera unsatisfied...\nRead more',
#  'Hello friends below mention are few review about POCO C55* By Look phone is nice* In this rang 7500/- nice phone* As I have buy this Phone to gift my mother & she is not using FB;Insta;Linkedin and social mediaso as of now phone is running very smooth* Battery is good* Camera at this rang is goodCons:* Refresh rate we can not change.* U will not get Phone Pin to open SIM tray\nRead more',
# ...

# %%
len(customer_reviews)
# Out:
# 8

# %%
len(cust_names)
# Out:
# 10

# %%
cust_names.pop()
# Out:
# 'MUKTHESH'

# %%
import pandas as pd
df=pd.DataFrame()

# %%
df["names"]=cust_names
df["reviews"]=customer_reviews

# %%
df
# Out:
#                                        names  \
# 0  POCO C55 (Power Black, 128 GB) (6 GB RAM)
# 1                            Amazon Customer
# 2                            Nandkumar Pawar
# 3                                      Gopal
# 4                          Anand kumar singh
# 5                                   Srinivas
# 6                               Paulami Laha
# 7                           Sanskriti Tagore
#
#                                              reviews
# 0  Plus points:1. 6gb RAM + good Processor at thi...
# 1  Display okBattery okLight weightGood for norma...
# 2  Hello friends below mention are few review abo...
# 3  The Poco55 for 7500 rupees with 6GB RAM and 12...
# 4  Awsome Battery Backup.. Good quality Camera......
# 5  Amazing phone worth of money and it looks very...
# 6  Battery charging takes very high time period i...
# 7  Everything is ok about this phoneBattery backu...

# %%
df.to_csv("C:\\Users\\Loyas\\OneDrive\\Desktop\\task output\\output.csv")
